# %% [markdown]
# ```
# Tasks Accomplished:
#
# I made an examples library for pulling in models for ease of use on development.
# Models included Michealis-Menten, TCE, LacOperon, and Schlogel.(No Umlauts, against PEP-8)
# [Read Original Bacteriophage Paper (1962), didn't understand how to derive rate kinetics]
#
# These have associative citations in PLOS Bioinformatics Style.
# (Is Cool?/Warranted? [Academia Ettiqute Question])
#
# Pulled and merged Python3 into Develop with new plot function.
# (The PR had been opened for two weeks, I thought we might want it done before research meeting.)
# [Possible Dick Move on my part]
#
# Worked on/almost finished with interactive graphing widget. [Will Demo.]
# Need to add a sleep/timeout functionality due to excessive load generated by constant recalculation of
# trajectories as populations change. [Act Dr. Sanft about reasonable population parmeters]
# [Utility is Hideous.]
# ```

# %%
import sys
import platform
import matplotlib.pyplot as plt
import numpy
import os
import timeit
sys.path.append("/home/jackson/Research/GillesPy2/")
import gillespy2

# %%
print(f'Benchmarks of System:\nPlatform: {platform.dist()[0]}\nProcessor: {platform.processor()}\nPython Build: {platform.python_version()}\nRunning off SSD\nMake And Model: Dell XPS 13 Develepor Edition Linux Variant')

# %%
from gillespy2.basic_root_solver import BasicRootSolver
from gillespy2.interactive_plot import *

# %%
from gillespy2.example_models import Trichloroethylene
model = Trichloroethylene()
plot_interactive(model, BasicRootSolver)

# %%
from gillespy2.example_models import MichaelisMenten
model = MichaelisMenten()
plot_interactive(model, BasicRootSolver)

# %% [markdown]
# ```
# Question about formatting reactions with multiple products: Assumed that reactants would have been comma delimenated, does not not work that way.
#
# CAIN Editing Model.
#
# Arkin Ros Gentics 1998
# ```
